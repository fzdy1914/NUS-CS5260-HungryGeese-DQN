# %%
# %load_ext autoreload
# %autoreload 2

from kaggle_environments import make
from board import encode_state, encode_env
from parameters import *
from model import ConvDQN
import torch
import numpy as np

env = make("hungry_geese", debug=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# env.run(['agent/wait_agent.py', 'agent/wait_agent.py', 'agent/wait_agent.py', 'agent/risk_averse_greedy.py'])
# # env.render(mode="ipython", height=600, width=800)

# # board, action, reward, done = encode_state(env.state)
# # buffer.add(board=board, action=action, reward=reward, next_board=board, done=done)

# print(buffer.get_buffer_size())
# print(buffer.get_stored_size())
# buffer.on_episode_end()
# print(buffer.get_stored_size())

# print(buffer.sample(32)['board'].shape)
# print(buffer.sample(32)['action'].shape)
# print(buffer.sample(32)['reward'].shape)
# print(buffer.sample(32)['done'].shape)
# print()
# # print(buffer)

# %%
env.reset(4)
print(env.done)
env.run(['agent/ConvDQNAgentWithSafeGuards.py', 'agent/ConvD3QNAgentWithSafeGuards.py', 'agent/boiler_goose.py', 'agent/risk_averse_greedy.py'])
print(env.done)
env.render(mode="ipython", height=600, width=800)
500
40
# for i in range(10):
#     print(env.steps[i][0], env.steps[i][0]["observation"]["geese"])
# Out:
# False
# danger pos
# 2. prev: NORTH 2.now: EAST
# danger pos
# 2. prev: EAST 2.now: NORTH
# 0. try opposite
# 0. prev: EAST 0.now: WEST
# try hit
# Goose Collision: WEST
# danger pos
# 2. prev: SOUTH 2.now: EAST
# try hit
# 1. prev: EAST 1.now: SOUTH
# danger pos
# 2. prev: NORTH 2.now: EAST
# 0. try opposite
# 0. prev: SOUTH 0.now: EAST
# Opposite action: (2, <Action.WEST: 4>, <Action.EAST: 2>)
# Goose Collision: WEST
# True
# <iframe srcdoc="<!--
#   Copyright 2020 Kaggle Inc
#
#   Licensed under the Apache License, Version 2.0 (the &quot;License&quot;);
#   you may not use this file except in compliance with the License.
#   You may obtain a copy of the License at
#
#       http://www.apache.org/licenses/LICENSE-2.0
#
#   Unless required by applicable law or agreed to in writing, software
#   distributed under the License is distributed on an &quot;AS IS&quot; BASIS,
#   WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
model = ConvDQN()

board_list, _, _, _ = encode_state(env.steps[0])

print(board_list[0].dtype)
t = torch.from_numpy(np.stack(board_list))
print(t.dtype)
t = t.unsqueeze(1).float()
print(t.dtype)
print(model.act(t, epsilon=0))
print(model.act(t, epsilon=0))
# Out:
# float64
# torch.float64
# torch.float32
# tensor([0, 0, 0, 0])
# tensor([0, 0, 0, 0])

# %%
print(env.state)
# Out:
# [{'action': 'NORTH', 'reward': 0, 'info': {}, 'observation': {'remainingOverageTime': 60, 'step': 0, 'geese': [[62]], 'food': [30, 28], 'index': 0}, 'status': 'ACTIVE'}]

# %%
env.step(["NORTH", "NORTH", "NORTH", "NORTH"])
print(env.state)
env.steps
# Out:
# ---------------------------------------------------------------------------
# InvalidArgument                           Traceback (most recent call last)
# <ipython-input-32-9a563dc9b8d9> in <module>
# ----> 1 env.step(["NORTH", "NORTH","NORTH","NORTH"])
#       2 print(env.state)
#
# D:\Anaconda3\envs\geese\lib\site-packages\kaggle_environments\core.py in step(self, actions, logs)
#     176             raise FailedPrecondition("Environment done, reset required.")
#     177         if not actions or len(actions) != len(self.state):
# --> 178             raise InvalidArgument(f"{len(self.state)} actions required.")
#     179
#     180         action_state = [0] * len(self.state)
#
# InvalidArgument: 1 actions required.
